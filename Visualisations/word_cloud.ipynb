# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
text = "Epilepsy Epilepsy Epilepsy Epilepsy Epilepsy Epilepsy Epilepsy seizure seizure seizure seizure seizure pain seizure free"

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image: lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# To create a mask
brain_mask = np.array(Image.open(r"brain_silhouette.png"))  # image of brain mask

# Create a word cloud image
wc = WordCloud(background_color="Purple", max_words=100, mask=brain_mask,
               contour_width=5, contour_color='black')  # colors cna be found https://matplotlib.org/2.0.0/examples/color/named_colors.html

# Generate a wordcloud
wc.generate(text)

# show
plt.figure(figsize=[20, 10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
